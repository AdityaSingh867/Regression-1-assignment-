# %% [markdown]
# Q1. Explain the difference between simple linear regression and multiple linear regression. Provide an
# example of each.

# %% [markdown]
# In Simple regression we take only one input (Independent) , but in multiple linear regression we take multiple input (Independent).

# %% [markdown]
# Q2. Discuss the assumptions of linear regression. How can you check whether these assumptions hold in
# a given dataset?

# %% [markdown]
# - All the variables are normally distributed
# - only one input in dataset.
# - There are no outliers

# %% [markdown]
# How can you check - by plot graph ,  to check use a test for detecting outliers.

# %% [markdown]
# Q3. How do you interpret the slope and intercept in a linear regression model? Provide an example using
# a real-world scenario.

# %% [markdown]
# the slope-intercept formula: y = mx + b
# - m is a slope.
# - y-intercept represents the starting point of the equation.

# %% [markdown]
# EXAMPLE - If the speed of the club hitting the ball increases by 1 mph, then the model predicts that the length the ball travels increases by 57.66 yards

# %% [markdown]
# Q4. Explain the concept of gradient descent. How is it used in machine learning?

# %% [markdown]
# gradient descent an optimization algorithm which is commonly-used to train machine learning models and neural networks

# %% [markdown]
# to find the values of a function's parameters (coefficients) that minimize a cost function as far as possible.

# %% [markdown]
# Q5. Describe the multiple linear regression model. How does it differ from simple linear regression?

# %% [markdown]
#  a regression model that estimates the relationship between a output dependent variable and two or more independent variables using a straight line

# %% [markdown]
# Simple linear regression has only one input (x) and one output (y) variable. Multiple linear regression has one output (y) and two or more input (x) variables.

# %% [markdown]
# Q6. Explain the concept of multicollinearity in multiple linear regression. How can you detect and
# address this issue?

# %% [markdown]
# Multicollinearity occurs when two or more independent variables have a high correlation with one another in a regression model

# %% [markdown]
# #### How can you detect
# - plot the correlation matrix of all the independent variables.
# - check multi-collinearity is to use the Variance Inflation Factor(VIF) for each independent variable.

# %% [markdown]
# Q7. Describe the polynomial regression model. How is it different from linear regression?

# %% [markdown]
# a machine learning model that can capture non-linear relationships between variables by fitting a non-linear regression line

# %% [markdown]
# How is it different.
#
# In linear regression the data point is distributed in a linear way but in polynomial regression data points is distributed in non linear way.
#
# EXAMPLE --

# %% [markdown]
# ![WhatsApp Image 2023-05-06 at 16.08.42.jpeg](attachment:2b0bd414-7e5c-46e6-94ef-31ce5d80c409.jpeg)

# %% [markdown]
# ![WhatsApp Image 2023-05-06 at 16.08.42 (1).jpeg](attachment:f77b74c6-a96c-40f0-a2c9-38aca2cd9f64.jpeg)

# %% [markdown]
# Q8. What are the advantages and disadvantages of polynomial regression compared to linear
# regression? In what situations would you prefer to use polynomial regression?

# %% [markdown]
# #### There is a disadvantage of a linear regression is that we can not make a best fit line for non linear distributed data points. on other hand there is a advantage of polynomial regression we creat a best fit line for non linear distributed and we also make best fit line for linear distributed.

# %% [markdown]
# ##### So , in linear data point distribution we use polynomial , linear regression to creat best fit line , But non linear data point distribution we use only polynomial regression.
